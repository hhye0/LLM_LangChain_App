# %%
import os
from dotenv import load_dotenv

load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
print(OPENAI_API_KEY[:2])
# Out:
# sk

# %% [markdown]
# ### <b>문제 3-1 :  콘텐츠분쟁해결 RAG 시스템 - 간단 실습 가이드</b>
# <b>문제 설명</b><br>
# : 콘텐츠분쟁해결 사례집을 활용한 법률 자문 RAG 시스템을 순차적으로 구축하는 실습입니다.

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate

print("===> 1. 문서 로딩 → PDF 읽기...")
loader = PyPDFLoader('../data/콘텐츠분쟁해결_사례.pdf')
documents = loader.load()
print(f"  총 {len(documents)}페이지 로드 완료")

print("===> 2. 문서 분할 → 작은 청크로 나누기")
pythontext_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1500,        # 청크 크기 (한국어 최적화)
    chunk_overlap=300,      # 중복 부분 (맥락 보존)
    separators=[
        "\n【사건개요】",     #  법률 문서 섹션 구분자
        "\n【쟁점사항】",     #  쟁점 부분 구분
        "\n【처리경위】",     #  처리 과정 구분
        "\n【처리결과】",     #  결과 부분 구분
        "\n■", "\n\n", "\n", ".", " ", ""
    ] # 자연스러운 분할을 위한 구분자
)
chunks = text_splitter.split_documents(documents)
print(f"  {len(chunks)}개 청크 생성 완료")
print(f"  평균 청크 길이: {sum(len(chunk.page_content) for chunk in chunks) / len(chunks):.0f}자")

print("===> 3. 벡터화 → 임베딩으로 변환")
pythonembeddings = OpenAIEmbeddings(
    model="text-embedding-3-large",  #  한국어 법률 용어에 최적
    dimensions=1536                  #  고성능 임베딩 차원
)

print("===> 4. 저장 → FAISS 벡터스토어에 저장")
vectorstore = FAISS.from_documents(chunks, embeddings)
print(f" FAISS 벡터스토어 생성 완료 ({len(chunks)}개 벡터)")

print("===> 5. 검색 → 질문과 유사한 문서 찾기")
retriever = vectorstore.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 5}  # 상위 6개 관련 문서 검색
)
print(" Retriever 설정 완료")

print("===> 6. 생성 → LLM으로 답변 생성")
pythonllm = ChatOpenAI(
    model="gpt-4o",                 #  또는 "gpt-4o-mini" (경제적)
    temperature=0.2,                #  법률 조언은 정확성 중시
    max_tokens=2000                 #  충분한 답변 길이
)

# 법률 자문 프롬프트 작성 
pythonprompt_template = """
당신은 콘텐츠 분야 전문 법률 자문사입니다. 
아래 분쟁조정 사례들을 바탕으로 정확하고 전문적인 법률 조언을 제공해주세요.

관련 분쟁사례:
{context}

상담 내용: {question}

답변 가이드라인:
1. 제시된 사례들을 근거로 답변하세요                  
2. 관련 법령이나 조항이 있다면 명시하세요              
3. 비슷한 사례의 처리경위와 결과를 참고하여 설명하세요  
4. 실무적 해결방안을 단계별로 제시하세요          
5. 사례에 없는 내용은 "제시된 사례집에서는 확인할 수 없습니다"라고 명시하세요 

전문 법률 조언:"""


prompt = PromptTemplate(
    template=pythonprompt_template,
    input_variables=["context", "question"]
)
print(" 프롬프트 설정 완료")

print("\n ===> 7.  QA 체인 생성...")
pythonqa_chain = RetrievalQA.from_chain_type(
    llm=pythonllm,                        
    chain_type="stuff",            
    retriever=retriever,           
    chain_type_kwargs={"prompt": prompt},  
    return_source_documents=True    
)
print("  RAG 파이프라인 구축 완료!")


print("\n ===> 8.  테스트 질문들")
pythontest_questions = [
    "온라인 게임에서 시스템 오류로 아이템이 사라졌는데, 게임회사가 복구를 거부하고 있습니다. 어떻게 해결할 수 있나요?",
    "인터넷 강의를 중도 해지하려고 하는데 과도한 위약금을 요구받고 있습니다. 정당한가요?",
    "무료체험 후 자동으로 유료전환되어 요금이 청구되었습니다. 환불 가능한가요?",
    "미성년자가 부모 동의 없이 게임 아이템을 구매했습니다. 환불받을 수 있는 방법이 있나요?",
    "온라인 교육 서비스가 광고와 다르게 제공되어 계약을 해지하고 싶습니다. 가능한가요?"
]

print("\n" + "=" * 60)
print(" RAG 시스템 테스트")
print("=" * 60)


print("\n ===> 9.  질문 및 답변 실행")
for i, question in enumerate(pythontest_questions, 1):
    print(f"\n【테스트 {i}/5】")
    print(f" 질문: {question}")
    print(" 답변 생성 중...")
    
    # RAG 실행
    result = pythonqa_chain.invoke({"query": question})
    answer = result["result"]
    source_docs = result["source_documents"]
    
    print(f"\n 답변:")
    print("-" * 50)
    print(answer)
    
    # 참조 문서 정보
    print(f"\n 참조 문서:")
    for j, doc in enumerate(source_docs[:3], 1):
        page = doc.metadata.get('page', 'N/A')
        preview = doc.page_content[:80].replace('\n', ' ')
        print(f"   {j}. 페이지 {page}: {preview}...")
    
    print("\n" + "-" * 40)
# Out:
# ===> 1. 문서 로딩 → PDF 읽기...
#   총 109페이지 로드 완료
# ===> 2. 문서 분할 → 작은 청크로 나누기
#   134개 청크 생성 완료
#   평균 청크 길이: 571자
# ===> 3. 벡터화 → 임베딩으로 변환
# ===> 4. 저장 → FAISS 벡터스토어에 저장
#  FAISS 벡터스토어 생성 완료 (134개 벡터)
# ===> 5. 검색 → 질문과 유사한 문서 찾기
#  Retriever 설정 완료
# ===> 6. 생성 → LLM으로 답변 생성
#  프롬프트 설정 완료
#
#  ===> 7.  QA 체인 생성...
#   RAG 파이프라인 구축 완료!
#
#  ===> 8.  테스트 질문들
#
# ============================================================
#  RAG 시스템 테스트
# ============================================================
#
#  ===> 9.  질문 및 답변 실행
#
# 【테스트 1/5】
#  질문: 온라인 게임에서 시스템 오류로 아이템이 사라졌는데, 게임회사가 복구를 거부하고 있습니다. 어떻게 해결할 수 있나요?
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# 온라인 게임에서 시스템 오류로 인해 아이템이 사라진 경우, 게임회사가 복구를 거부하는 상황에 대한 법률 조언을 드리겠습니다. 제시된 사례들을 근거로 하여 답변을 구성하였습니다.
#
# 1. **사례 분석**:
#    - **사례 1**: 시스템 오류로 아이템이 소멸되었으나, 계정 명의자가 아니어서 복구가 거부된 사례입니다. 이 경우, 계정 명의자가 직접 복구 요청을 해야 한다는 점이 강조되었습니다.
#    - **사례 23**: 시스템 오류로 인한 게임머니 손실을 주장했으나, 시스템 오류가 발생하지 않았다는 게임사의 입장과 사용 내역을 근거로 복구가 거부된 사례입니다.
#    - **사례 13**: 보안 서비스 미작동으로 인한 아이템 도난에 대해, 게임사가 도난을 인정하고 복구를 권고받은 사례입니다.
#
# 2. **관련 법령**:
#    - 민법 제250조 및 제251조는 도품이나 유실물에 대한 반환 청구에 관한 규정을 두고 있습니다. 그러나 이는 주로 물리적 재산에 대한 것이며, 디지털 아이템에 직접 적용되지는 않습니다.
#
# 3. **비슷한 사례의 처리경위 및 결과**:
#    - 시스템 오류로 인한 손실에 대해 게임사가 오류 발생을 인정하지 않거나, 계정 명의 문제로 복구가 거부된 사례가 있었습니다. 반면, 보안 서비스의 미작동이 인정된 경우에는 복구가 권고되었습니다.
#
# 4. **실무적 해결방안**:
#    - **1단계**: 게임사의 약관 및 정책을 검토하여, 시스템 오류로 인한 손실에 대한 보상 규정이 있는지 확인합니다.
#    - **2단계**: 계정 명의 문제를 해결합니다. 계정 명의자가 아닌 경우, 명의자가 직접 복구 요청을 하도록 합니다.
#    - **3단계**: 시스템 오류 발생 여부를 객관적으로 입증할 수 있는 증거를 수집합니다. 예를 들어, 오류 발생 시점의 스크린샷, 로그 기록 등을 확보합니다.
#    - **4단계**: 게임사에 공식적으로 이의제기를 하고, 고객센터를 통해 문제 해결을 요청합니다. 이때, 수집한 증거를 함께 제출합니다.
#    - **5단계**: 게임사가 복구를 거부할 경우, 한국소비자원 등 관련 기관에 중재를 요청할 수 있습니다.
#
# 5. **추가 정보**:
#    - 제시된 사례집에서는 시스템 오류로 인한 아이템 손실에 대한 구체적인 법적 해결책은 확인할 수 없습니다. 다만, 위의 단계를 통해 문제 해결을 시도할 수 있습니다.
#
# 이와 같은 절차를 통해 문제를 해결하시길 권장드립니다. 추가적인 법적 조언이 필요하시면, 전문 변호사와 상담하시기 바랍니다.
#
#  참조 문서:
#    1. 페이지 8: 1. 게임 3 게임1 ■ 1-가-1) 한국소비자원 조정전 상담사례2006_시스템 오류로 소멸된 아이템 복구 요구【사건개요】신청인은 피신청인이 제...
#    2. 페이지 28: 1. 게임 23 ■ 1-가-1) 한국소비자원 조정전 상담사례2009_시스템 오류로 인한 손실 아이템 복구 요구【사건개요】신청인은 2009. 9....
#    3. 페이지 30: 1. 게임 25 ■ 1-가-1) 한국소비자원 조정전 상담사례2009_해킹으로 손실된 아이템 복구 요청【사건개요】피청구인이 제공하는 게임서비스 가...
#
# ----------------------------------------
#
# 【테스트 2/5】
#  질문: 인터넷 강의를 중도 해지하려고 하는데 과도한 위약금을 요구받고 있습니다. 정당한가요?
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# 인터넷 강의를 중도 해지하려는 경우, 과도한 위약금을 요구받고 있는 상황에 대한 법률 조언을 드리겠습니다.
#
# 1. **사례 근거**:
#    - 제시된 사례들에서는 인터넷 교육 서비스의 중도 해지 시, 위약금 및 환급금 산정에 대한 분쟁이 자주 발생하고 있습니다. 특히, 소비자분쟁해결기준에 따르면, 해지일까지의 이용일수에 해당하는 금액과 총 이용금액의 10%를 공제한 후 환급하는 것이 일반적인 처리 방식입니다.
#
# 2. **관련 법령**:
#    - **방문판매 등에 관한 법률 제29조**: 계약의 해지에 관한 규정이 있으며, 이는 계약 해지 시 위약금 및 환급금 산정의 근거가 됩니다.
#    - **소비자기본법에 따른 소비자분쟁해결기준**: 인터넷 콘텐츠업의 경우, 해지일까지의 이용일수에 해당하는 금액과 총 이용금액의 10%를 공제 후 환급하도록 규정하고 있습니다.
#
# 3. **비슷한 사례의 처리경위와 결과**:
#    - 2007년 사례에서는 피신청인이 과도한 위약금을 공제하려 했으나, 소비자분쟁해결기준에 따라 환급금이 산정되었습니다.
#    - 2010년 사례에서는 화상불량으로 인한 중도 해지 시, 실제 이용일수를 기준으로 환급금이 산정되었습니다.
#
# 4. **실무적 해결방안**:
#    - **계약서 확인**: 먼저, 계약서에 명시된 환불 및 위약금 규정을 확인하세요. 계약서에 명시된 내용이 법령 및 소비자분쟁해결기준과 일치하는지 검토합니다.
#    - **소비자분쟁해결기준 적용**: 위약금이 과도하게 책정되었다면, 소비자분쟁해결기준에 따라 해지일까지의 이용일수에 해당하는 금액과 총 이용금액의 10%를 공제한 후 환급을 요구할 수 있습니다.
#    - **조정 신청**: 사업자가 이를 거부할 경우, 한국소비자원이나 전자거래분쟁조정위원회에 조정을 신청하여 분쟁 해결을 시도할 수 있습니다.
#    - **법적 조치**: 조정이 실패할 경우, 법적 절차를 통해 해결을 모색할 수 있습니다.
#
# 5. **사례에 없는 내용**:
#    - 제시된 사례집에서는 계약 해지 시 위약금의 구체적인 산정 방식이나 추가적인 법적 절차에 대한 내용은 확인할 수 없습니다.
#
# 이러한 조언을 바탕으로, 귀하의 상황에 맞는 적절한 조치를 취하시길 바랍니다. 추가적인 법적 조언이 필요하다면, 전문 변호사와 상담하시기를 권장합니다.
#
#  참조 문서:
#    1. 페이지 3: . 이러닝···········································································...
#    2. 페이지 62: 2. 이러닝 57 ■ 2-가 한국소비자원 조정결정례2007_인터넷교육서비스 중도해지 요구【사건개요】청구인은 2006. 2. 8. 피청구인이 운영...
#    3. 페이지 75: 콘텐츠분쟁조정 법리 연구 2부 - 타 분쟁조정사례 조사 - 70 하기 위하여 제정된 소비자분쟁해결기준은 인터넷컨텐츠업의 경우 해지일까지의 이용일...
#
# ----------------------------------------
#
# 【테스트 3/5】
#  질문: 무료체험 후 자동으로 유료전환되어 요금이 청구되었습니다. 환불 가능한가요?
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# 무료체험 후 자동으로 유료 전환되어 요금이 청구된 경우, 환불 가능 여부에 대한 법률 조언을 드리겠습니다.
#
# 1. **계약 체결 시 중요 내용 명시 및 고지 의무**:
#    - 제시된 사례들에서 공통적으로 문제된 부분은 계약 체결 시 중요한 내용이 충분히 명시되지 않았다는 점입니다. 특히, 무료 체험 후 자동으로 유료 전환된다는 사실이 소비자에게 명확히 고지되지 않았을 경우, 이는 「약관의 규제에 관한 법률」 제3조에 따른 약관의 작성 및 설명의무 위반에 해당할 수 있습니다.
#
# 2. **관련 법령**:
#    - 「약관의 규제에 관한 법률」 제3조: 약관의 작성 및 설명의무
#    - 「소비자기본법」에 따른 소비자분쟁해결기준
#    - 「방문판매 등에 관한 법률」 제29조: 계약 해지에 관한 규정
#
# 3. **비슷한 사례의 처리 경위와 결과**:
#    - 사례에서는 피신청인이 계약 해지 및 유료 전환에 대한 내용을 충분히 고지하지 않았다는 이유로 소비자에게 환불을 권고하였습니다. 또한, 소비자가 계약 해지를 요청할 경우, 피신청인은 잔여 이용 요금을 환급해야 한다는 결정이 내려졌습니다.
#
# 4. **실무적 해결 방안**:
#    - **첫 번째 단계**: 계약 체결 시 고지된 내용과 실제로 고지된 내용이 일치하는지 확인합니다. 특히, 유료 전환에 대한 고지가 명확히 이루어졌는지 검토합니다.
#    - **두 번째 단계**: 계약 해지 의사를 명확히 전달합니다. 이는 내용증명 우편 등을 통해 공식적으로 통지하는 것이 좋습니다.
#    - **세 번째 단계**: 환불 요청을 공식적으로 제출합니다. 이때, 계약 해지 및 환불 요청의 근거를 명확히 제시합니다.
#    - **네 번째 단계**: 피신청인이 환불을 거부할 경우, 소비자분쟁조정위원회나 관련 기관에 조정을 신청합니다.
#
# 5. **사례에 없는 내용**:
#    - 제시된 사례집에서는 특정한 환불 절차나 추가적인 법적 조치에 대한 내용은 확인할 수 없습니다.
#
# 이와 같은 절차를 통해 문제를 해결할 수 있으며, 필요시 법률 전문가의 추가적인 조언을 받는 것도 고려해 보시기 바랍니다.
#
#  참조 문서:
#    1. 페이지 100: 3. 기타(웹) 95 ■ 3-가 한국소비자원 조정결정례2010_무료 이벤트 후 자동 소액 결제 요금 환급요구【사건개요】신청인은 2008. 12....
#    2. 페이지 69: 콘텐츠분쟁조정 법리 연구 2부 - 타 분쟁조정사례 조사 - 64 사용하여 반환받을 수 있는 서비스가 아니므로 미 이용기간에 해당하는 대금을 환급...
#    3. 페이지 103: 콘텐츠분쟁조정 법리 연구 2부 - 타 분쟁조정사례 조사 - 98 뿐만 아니라 이용자가 가입 후 해지를 원할 때 일정기간 해지를 못하게 한다거나 ...
#
# ----------------------------------------
#
# 【테스트 4/5】
#  질문: 미성년자가 부모 동의 없이 게임 아이템을 구매했습니다. 환불받을 수 있는 방법이 있나요?
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# 미성년자가 부모의 동의 없이 게임 아이템을 구매한 경우, 환불을 받을 수 있는 가능성은 여러 요소에 따라 달라질 수 있습니다. 제시된 사례들을 바탕으로 다음과 같은 법률 조언을 드립니다.
#
# 1. **미성년자의 법적 능력**: 민법 제5조에 따르면, 미성년자는 법정대리인의 동의 없이 법률행위를 할 수 없습니다. 따라서 미성년자가 부모의 동의 없이 게임 아이템을 구매한 경우, 해당 거래는 원칙적으로 취소가 가능합니다.
#
# 2. **사술의 사용 여부**: 민법 제17조에 따르면, 미성년자가 사술을 사용하여 성인으로 오인하게 만든 경우에는 계약 취소가 제한될 수 있습니다. 제시된 사례에서 미성년자가 타인의 명의를 도용하거나 성인인 것처럼 가장하여 거래를 한 경우, 이는 사술로 간주될 수 있으며, 이 경우 계약 취소가 어려울 수 있습니다.
#
# 3. **부당이득 반환 청구**: 민법 제741조에 따르면, 계약이 취소되면 부당이득으로서 반환의 대상이 됩니다. 즉, 미성년자가 부모 동의 없이 구매한 게임 아이템에 대한 거래가 취소되면, 해당 금액은 부당이득으로 반환되어야 합니다.
#
# 4. **사례 참고**: 제시된 사례에서는 미성년자가 타인의 명의를 도용하여 결제한 경우, 사술로 판단되어 계약 취소가 어려웠습니다. 그러나 미성년자 본인의 명의로 결제한 경우에는 계약이 취소되어 환불이 가능했습니다.
#
# 5. **실무적 해결방안**:
#    - **거래 내역 확인**: 우선, 미성년자가 구매한 내역을 확인하고, 해당 거래가 미성년자 본인의 명의로 이루어졌는지, 타인의 명의를 도용했는지 확인해야 합니다.
#    - **게임사에 요청**: 미성년자 본인의 명의로 거래가 이루어진 경우, 게임사에 계약 취소 및 환불을 요청할 수 있습니다. 이때, 미성년자임을 증명할 수 있는 서류(예: 주민등록등본)를 함께 제출하는 것이 좋습니다.
#    - **분쟁조정 신청**: 게임사가 환불 요청을 거부할 경우, 전자거래분쟁조정위원회에 분쟁조정을 신청할 수 있습니다. 이때, 미성년자임을 증명할 수 있는 자료와 함께 거래 내역을 제출해야 합니다.
#
# 6. **추가적인 법적 조치**: 제시된 사례집에서는 확인할 수 없습니다. 그러나 필요시 법률 전문가의 도움을 받아 추가적인 법적 조치를 고려할 수 있습니다.
#
# 이와 같은 절차를 통해 미성년자가 부모 동의 없이 구매한 게임 아이템에 대한 환불을 받을 수 있는 가능성을 높일 수 있습니다.
#
#  참조 문서:
#    1. 페이지 53: . 실제 온라인상에서는 이처럼 많은 게임머니가 필요하지 않으므로 이는 처음부터 현금화 하려는 목적으로 당사에서 게임머니를 구매한 뒤 여타 다른 ...
#    2. 페이지 50: 1. 게임 45 ■ 1-나 전자거래분쟁조정위원회 조정결정례2008_부당결제대금 반환 청구【사건개요】신청인의 자녀는 2004. 4. 22. 피신청...
#    3. 페이지 52: . 당시 비밀번호를 아들이 만들어주어서 결제가 가능했음.  ㆍ 피신청인 아들의 전화상 음성이 성년으로 짐작된다는 주장을 인정할 수 없으며, 만일...
#
# ----------------------------------------
#
# 【테스트 5/5】
#  질문: 온라인 교육 서비스가 광고와 다르게 제공되어 계약을 해지하고 싶습니다. 가능한가요?
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# 온라인 교육 서비스가 광고와 다르게 제공되어 계약을 해지하고 싶다는 상담 내용에 대해, 제시된 사례들을 근거로 다음과 같이 답변 드리겠습니다.
#
# 1. **계약 해지 가능 여부**:
#    - 제시된 사례들에서 공통적으로 나타나는 것은, 온라인 교육 서비스 계약의 해지는 가능하다는 점입니다. 특히, 「방문판매 등에 관한 법률」 제29조에 따라 계속적 거래에 해당하는 계약은 언제든지 해지할 수 있습니다.
#
# 2. **관련 법령**:
#    - 「방문판매 등에 관한 법률」 제29조: 계약의 해지
#    - 「방문판매 등에 관한 법률」 제30조: 계약의 해지 또는 해제의 효과와 위약금 등
#    - 소비자기본법에 따른 소비자분쟁해결기준(공정위고시, 인터넷콘텐츠업)
#
# 3. **비슷한 사례의 처리경위와 결과**:
#    - 사례 69에서는 계약 해지 의사 표시 후 적법하게 해지되었으며, 피신청인이 총 이용요금의 2/3를 공제하겠다는 주장은 받아들여지지 않았습니다. 이는 계약 해지로 인해 발생하는 손실을 초과하는 위약금을 청구할 수 없다는 법령에 근거합니다.
#    - 사례 88에서는 피신청인이 환불 기준에 따라 이용금액과 총금액의 10%를 공제한 금액을 환불하였으나, 신청인은 이를 거부하고 전체금액의 10% 공제를 요구하였습니다.
#
# 4. **실무적 해결방안**:
#    - **1단계**: 계약 해지 의사를 명확히 표시하십시오. 이는 서면으로 하는 것이 좋습니다.
#    - **2단계**: 피신청인의 환불 기준을 확인하고, 해당 기준이 소비자에게 불리하지 않은지 검토하십시오.
#    - **3단계**: 환불 기준이 불리하다면, 소비자분쟁해결기준에 따라 적정한 환불을 요구하십시오.
#    - **4단계**: 분쟁이 지속될 경우, 전자거래분쟁조정위원회나 한국소비자원에 조정을 신청하여 중재를 받으십시오.
#
# 5. **사례에 없는 내용**:
#    - 광고와 실제 제공된 서비스의 차이에 대한 구체적인 법적 기준이나 판례는 제시된 사례집에서는 확인할 수 없습니다. 이 경우, 추가적인 법률 자문을 통해 구체적인 상황에 맞는 조언을 받으시는 것이 좋습니다.
#
# 이와 같은 절차를 통해 계약 해지 및 환불 문제를 해결하시기 바랍니다. 추가적인 법적 조언이 필요하시면 전문 변호사와 상담하시기를 권장드립니다.
#
#  참조 문서:
#    1. 페이지 94: 2. 이러닝 89 상기 내용을 살펴보면, 신청인은 청약철회 기간을 지났으므로 위 계약의 청약을 철회할 수는 없는 것으로 보인다. 피신청인은 위 ...
#    2. 페이지 93: 콘텐츠분쟁조정 법리 연구 2부 - 타 분쟁조정사례 조사 - 88 ■ 2-다 전자거래분쟁조정위원회 조정결정례2008_온라인 동영상 강의 계약 해지...
#    3. 페이지 62: 2. 이러닝 57 ■ 2-가 한국소비자원 조정결정례2007_인터넷교육서비스 중도해지 요구【사건개요】청구인은 2006. 2. 8. 피청구인이 운영...
#
# ----------------------------------------
